# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv('/content/nigeria_houses_data.csv')

# %%
df
# Out:
#        bedrooms  bathrooms  toilets  parking_space                 title  \
# 0           6.0        5.0      5.0            4.0       Detached Duplex
# 1           4.0        5.0      5.0            4.0     Terraced Duplexes
# 2           4.0        5.0      5.0            4.0       Detached Duplex
# 3           4.0        4.0      5.0            6.0       Detached Duplex
# 4           4.0        4.0      5.0            2.0  Semi Detached Duplex
# ...         ...        ...      ...            ...                   ...
# 24321       2.0        2.0      2.0            4.0        Block of Flats
# 24322       4.0        5.0      5.0            4.0        Block of Flats
# 24323       4.0        5.0      5.0            4.0       Detached Duplex
# 24324       3.0        4.0      4.0            3.0        Block of Flats
# 24325       4.0        5.0      5.0            4.0       Detached Duplex
#
#                        town  state        price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24326 entries, 0 to 24325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       24326 non-null  float64
#  1   bathrooms      24326 non-null  float64
#  2   toilets        24326 non-null  float64
#  3   parking_space  24326 non-null  float64
#  4   title          24326 non-null  object
#  5   town           24326 non-null  object
#  6   state          24326 non-null  object
#  7   price          24326 non-null  float64
# dtypes: float64(5), object(3)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#            bedrooms     bathrooms       toilets  parking_space         price
# count  24326.000000  24326.000000  24326.000000   24326.000000  2.432600e+04
# mean       4.338814      4.600798      5.176355       4.041725  3.013802e+08
# std        1.138497      1.163161      1.226253       1.399936  1.220403e+10
# min        1.000000      1.000000      1.000000       1.000000  9.000000e+04
# 25%        4.000000      4.000000      5.000000       4.000000  5.200000e+07
# 50%        4.000000      5.000000      5.000000       4.000000  8.500000e+07
# 75%        5.000000      5.000000      6.000000       4.000000  1.600000e+08
# max        9.000000      9.000000      9.000000       9.000000  1.800000e+12

# %%
df['title'].unique()
# Out:
# array(['Detached Duplex', 'Terraced Duplexes', 'Semi Detached Duplex',
#        'Detached Bungalow', 'Block of Flats', 'Semi Detached Bungalow',
#        'Terraced Bungalow'], dtype=object)

# %%
df['state'].unique()
# Out:
# array(['Abuja', 'Lagos', 'Edo', 'Ogun', 'Oyo', 'Imo', 'Anambara',
#        'Rivers', 'Enugu', 'Kaduna', 'Kwara', 'Nasarawa', 'Abia', 'Delta',
#        'Akwa Ibom', 'Osun', 'Ekiti', 'Cross River', 'Kogi', 'Plateau',
#        'Kano', 'Katsina', 'Bayelsa', 'Borno', 'Niger'], dtype=object)

# %%
df['town'].unique()
# Out:
# array(['Mabushi', 'Katampe', 'Lekki', 'Ajah', 'Epe', 'Lokogoma District',
#        'Oredo', 'Victoria Island (VI)', 'Mowe Ofada', 'Ikeja', 'Ikoyi',
#        'Magodo', 'Kaura', 'Galadimawa', 'Gwarinpa', 'Abeokuta North',
#        'Lugbe District', 'Ibeju Lekki', 'Yaba', 'Sango Ota',
#        'Ifako-Ijaiye', 'Agege', 'Ikorodu', 'Jahi', 'Ibadan', 'Orozo',
#        'Ifo', 'Owerri North', 'Guzape District', 'Idu Industrial',
#        'Owerri Municipal', 'Isheri North', 'Utako', 'Port Harcourt',
#        'Kuje', 'Isheri', 'Life Camp', 'Ipaja', 'Ado-Odo/Ota', 'Dape',
#        'Mushin', 'Ejigbo', 'Isolo', 'Ojodu', 'Gaduwa', 'Enugu', 'Dakwo',
#        'Asokoro District', 'Alimosho', 'Sagamu', 'Chikun', 'Egbeda',
#        'Wuye', 'Kubwa', 'Shomolu', 'Ogudu', 'Owerri West', 'Ibafo',
#        'Surulere', 'Obio-Akpor', 'Ayobo', 'Apo', 'Mowe Town',
#        'Ibadan South-West', 'Wuse 2', 'Durumi', 'Simawa', 'Arepo',
#        'Ikotun', 'Oluyole', 'Maitama District', 'Maryland', 'Ido',
# ...

# %% [markdown]
# # DATA PROCESSING

# %%
#Encoding
# dont encode int only values with true or false
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()
# LabelEncoder gives reoccuring item a unique no within the column
df['title'] = le.fit_transform(df['title'])
df['town'] = le.fit_transform(df['town'])
df['state'] = le.fit_transform(df['state'])
df
# Out:
#        bedrooms  bathrooms  toilets  parking_space  title  town  state  \
# 0           6.0        5.0      5.0            4.0      2   127      1
# 1           4.0        5.0      5.0            4.0      6   110      1
# 2           4.0        5.0      5.0            4.0      2   122     17
# 3           4.0        4.0      5.0            6.0      2    10     17
# 4           4.0        4.0      5.0            2.0      4   122     17
# ...         ...        ...      ...            ...    ...   ...    ...
# 24321       2.0        2.0      2.0            4.0      0    99      1
# 24322       4.0        5.0      5.0            4.0      0     5     20
# 24323       4.0        5.0      5.0            4.0      2   122     17
# 24324       3.0        4.0      4.0            3.0      0   180     17
# 24325       4.0        5.0      5.0            4.0      2   122     17
#
#              price
# 0      450000000.0
# 1      800000000.0
# 2      120000000.0
# 3       40000000.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24326 entries, 0 to 24325
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bedrooms       24326 non-null  float64
#  1   bathrooms      24326 non-null  float64
#  2   toilets        24326 non-null  float64
#  3   parking_space  24326 non-null  float64
#  4   title          24326 non-null  int64
#  5   town           24326 non-null  int64
#  6   state          24326 non-null  int64
#  7   price          24326 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 1.5 MB

# %%
x = df.drop(['price'], axis=1)
y = df['price']

# %%
x
# Out:
#        bedrooms  bathrooms  toilets  parking_space  title  town  state
# 0           6.0        5.0      5.0            4.0      2   127      1
# 1           4.0        5.0      5.0            4.0      6   110      1
# 2           4.0        5.0      5.0            4.0      2   122     17
# 3           4.0        4.0      5.0            6.0      2    10     17
# 4           4.0        4.0      5.0            2.0      4   122     17
# ...         ...        ...      ...            ...    ...   ...    ...
# 24321       2.0        2.0      2.0            4.0      0    99      1
# 24322       4.0        5.0      5.0            4.0      0     5     20
# 24323       4.0        5.0      5.0            4.0      2   122     17
# 24324       3.0        4.0      4.0            3.0      0   180     17
# 24325       4.0        5.0      5.0            4.0      2   122     17
#
# [24326 rows x 7 columns]

# %%
y
# Out:
# 0        450000000.0
# 1        800000000.0
# 2        120000000.0
# 3         40000000.0
# 4         75000000.0
#             ...
# 24321     15000000.0
# 24322     25000000.0
# 24323     68000000.0
# 24324     78000000.0
# 24325     65000000.0
# Name: price, Length: 24326, dtype: float64

# %%
# data split into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (17028, 7)
# (7298, 7)
# (17028,)
# (7298,)

# %% [markdown]
# End of training

# %%
# IMPORT LINEAR REGRESSION MODEL
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
pd.DataFrame({
    'y test': y_test,
    'y prediction' : y_pred
})
# Out:
#             y test  y prediction
# 16414  155000000.0  8.864909e+08
# 19967   50000000.0  6.020983e+08
# 12575   60000000.0  1.405420e+08
# 13906   98000000.0 -8.331296e+07
# 19847  400000000.0  4.768431e+08
# ...            ...           ...
# 19785   75000000.0  1.351865e+08
# 10628   80000000.0  1.558422e+08
# 6126   180000000.0  6.314603e+08
# 1373    55000000.0  7.461299e+08
# 7094   250000000.0  3.736317e+08
#
# [7298 rows x 2 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test, y_pred)
print(f'The mean squared error is{mse}')
# Out:
# The mean squared error is3.208114832260711e+17

# %%
#calculate root mean sqared error
rmse = np.sqrt(mse)
print(f'The root mean squared error is {rmse}')
# Out:
# The root mean squared error is 566402227.4197649

# %%
df.iloc[1]
# Out:
# bedrooms                 4.0
# bathrooms                5.0
# toilets                  5.0
# parking_space            4.0
# title                    6.0
# town                   110.0
# state                    1.0
# price            800000000.0
# Name: 1, dtype: float64

# %%
h1 = df.iloc[1].drop(['price'])

# %%
h1 = pd.DataFrame({
    'bedrooms' : 4.0,
    'bathrooms' : 5.0,
    'toilets' : 5.0,
    'parking_space' : 4.0,
    'title' : 6.0,
    'town' : 110.0,
    'state' : 1.0
}, index=[0])

# %%
lr.predict(h1)
#predicted price for that house
# Out:
# array([2.88063165e+08])

# %% [markdown]
# # DATA VISUALIZATION

# %%
df.head()
# Out:
#    bedrooms  bathrooms  toilets  parking_space  title  town  state  \
# 0       6.0        5.0      5.0            4.0      2   127      1
# 1       4.0        5.0      5.0            4.0      6   110      1
# 2       4.0        5.0      5.0            4.0      2   122     17
# 3       4.0        4.0      5.0            6.0      2    10     17
# 4       4.0        4.0      5.0            2.0      4   122     17
#
#          price
# 0  450000000.0
# 1  800000000.0
# 2  120000000.0
# 3   40000000.0
# 4   75000000.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
data = pd.read_csv('/content/nigeria_houses_data.csv')

# %%
data[data.state == 'Borno']
# to print out those in borno
# Out:
#        bedrooms  bathrooms  toilets  parking_space              title  \
# 10343       4.0        4.0      5.0            4.0  Terraced Duplexes
# 23415       4.0        4.0      5.0            4.0  Terraced Duplexes
#
#            town  state        price
# 10343  Guzamala  Borno  105000000.0
# 23415  Guzamala  Borno  105000000.0

# %% [markdown]
# sns.barplot(x=data.state, y=data.price)
#
# plt.xticks(rotation=90)
#
# or

# %%
plt.figure(figsize=(10, 10))
sns.barplot(x='state', y='price', data=df)
plt.title('Price of house by each State')
plt.xlabel('state')
plt.ylabel('price')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# to predict price of a house

# %% [markdown]
# where blue reaches average and black is maximum

# %%
plt.figure(figsize=(10, 10))

# %%
sns.pairplot(data)

# %% [markdown]
# # RANDOM FOREST REGRESSOR

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_rf = rf.predict(x_test)

# %%
pd.DataFrame({
    'y test' : y_test,
    'y pred rf' : y_pred_rf
})
# Out:
#             y test     y pred rf
# 16414  155000000.0  1.480980e+08
# 19967   50000000.0  9.703985e+07
# 12575   60000000.0  8.680153e+07
# 13906   98000000.0  2.837517e+08
# 19847  400000000.0  2.699084e+08
# ...            ...           ...
# 19785   75000000.0  9.818485e+07
# 10628   80000000.0  7.055848e+07
# 6126   180000000.0  1.710840e+08
# 1373    55000000.0  8.159379e+07
# 7094   250000000.0  4.434960e+08
#
# [7298 rows x 2 columns]

# %%
mse = mean_squared_error(y_test, y_pred_rf)
print(f'The mean squared error for Random Forest is {mse}')
# Out:
# The mean squared error for Random Forest is 1.435501535940865e+20

# %%
rmse = np.sqrt(mse)
print(f'The root mean squared error is {rmse}')
# Out:
# The root mean squared error is 11981241738.404518

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_dt = dt.predict(x_test)

# %%
pd.DataFrame({
    'y test' : y_test,
    'y pred dt' : y_pred_dt
})
# Out:
#             y test     y pred dt
# 16414  155000000.0  1.500000e+08
# 19967   50000000.0  8.062500e+07
# 12575   60000000.0  8.525000e+07
# 13906   98000000.0  2.839655e+08
# 19847  400000000.0  2.929739e+08
# ...            ...           ...
# 19785   75000000.0  9.868234e+07
# 10628   80000000.0  7.061538e+07
# 6126   180000000.0  1.714913e+08
# 1373    55000000.0  8.142857e+07
# 7094   250000000.0  2.650000e+08
#
# [7298 rows x 2 columns]

# %% [markdown]
# # LASSO REGRESSION

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=0.1)

# %%
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.1)

# %%
y_pred_lasso = lasso_reg.predict(x_test)
